# %% [markdown]
# # RandomForest

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
df_real = pd.read_csv('../data/balanced_real_data.csv')
df_fake = pd.read_csv('../data/balanced_fake_data.csv')

# %%
df=pd.concat([df_real,df_fake],ignore_index=True)

# %%
features=list(df.columns[:30])
print(features_columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-54fb39777831> in <module>
#       1 features=list(df.columns[:30])
# ----> 2 print(features_columns)
#
# NameError: name 'features_columns' is not defined

# %%
targets = df['real_account'].values
df=df.loc[:,'profile_pic':'highlight_reel_count']
features=df.loc[:,'profile_pic':'highlight_reel_count']
df=df.loc[:,'profile_pic':'highlight_reel_count']
df.shape
print(features)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-db0bcb2c2915> in <module>
# ----> 1 targets = df['real_account'].values
#       2 df=df.loc[:,'profile_pic':'highlight_reel_count']
#       3 features=df.loc[:,'profile_pic':'highlight_reel_count']
#       4 df=df.loc[:,'profile_pic':'highlight_reel_count']
#       5 df.shape
#
# NameError: name 'df' is not defined

# %%
targets
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
# df.drop('real_account', axis=1, inplace=True)

# %%
df.head()
# Out:
#    profile_pic  biography  follows_count  followed_by_count       ff_ratio  \
# 0         True         11            597           13156189   22037.167504
# 1         True          0            423                192       0.453901
# 2         True          0            426                151       0.354460
# 3         True        128            450                694       1.542222
# 4         True         60              1             327728  327728.000000
#
#    media_count  is_private  is_verified  is_business_account  \
# 0         1592       False         True                False
# 1           50        True        False                False
# 2           37       False        False                False
# 3         1144       False        False                False
# 4          392       False        False                 True
#
#    is_joined_recently  highlight_reel_count
# 0               False                    15
# 1               False                     0
# 2               False                     2
# 3               False                    10
# 4               False                     1

# %%
x_train, x_test, y_train, y_test = train_test_split(df, targets, test_size = 0.2, random_state = 12345)

# %%
dtc = DecisionTreeClassifier(random_state=0,max_depth=5)

# %%
dtc.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=0, splitter='best')

# %%
dtc_pred = dtc.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, dtc_pred))
# Out:
# [[1397  164]
#  [ 117 1384]]

# %%
print(classification_report(y_test, dtc_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.92      0.89      0.91      1561
#         True       0.89      0.92      0.91      1501
#
#     accuracy                           0.91      3062
#    macro avg       0.91      0.91      0.91      3062
# weighted avg       0.91      0.91      0.91      3062

# %%
from sklearn import tree
import pydotplus
from IPython.display import Image

features=list(df.columns[0:11])

# %%
dot_data = tree.export_graphviz(dtc, out_file=None,
                         feature_names=features,class_names=['Fake','Real'],
                         filled=True, rounded=True,  
                         special_characters=True)  
graph = pydotplus.graph_from_dot_data(dot_data)  
Image(graph.create_png())
