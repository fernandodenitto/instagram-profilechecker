# %% [markdown]
# # Dataset Analysis

# %% [markdown]
# The aim of this Jupyter Notebook is to navigate the Dataset used on the project for the users classification in Instagram. It is a labelled dataset where the label is the column 'real_account' with the possible values true (for the real users) and false (for the fake ones).

# %% [markdown]
# # Import the context (libraries) and the dataset (already processed)

# %%
import pandas as pd
import numpy as np

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import StandardScaler

# %%
df_real = pd.read_csv('../data/balanced_real_data.csv')
df_fake = pd.read_csv('../data/balanced_fake_data.csv')

# %% [markdown]
# # Fast view of Real and Fake Users Datasets

# %%
df_real.head()
# Out:
#              username  profile_pic  biography  follows_count  \
# 0          irinashayk         True         11            597
# 1  dementieva_a______         True          0            423
# 2         lorenz.fini         True          0            426
# 3       jessicagiulia         True        128            450
# 4        il_socio_aci         True         60              1
#
#    followed_by_count       ff_ratio  media_count  is_private  is_verified  \
# 0           13156189   22037.167504         1592       False         True
# 1                192       0.453901           50        True        False
# 2                151       0.354460           37       False        False
# 3                694       1.542222         1144       False        False
# 4             327728  327728.000000          392       False        False
#
#    is_business_account  ...  std_comments   var_comments  skw_comments  \
# 0                False  ...    878.448591  771671.926667      2.252054
# 1                False  ...           NaN            NaN           NaN
# 2                False  ...      2.827248       7.993333      4.049417
# 3                False  ...      1.683251       2.833333      0.963009
# 4                 True  ...    123.279128   15197.743333      2.519276
#
#    mean_time_between_posts  max_time_between_posts  min_time_between_posts  \
# 0             2.077083e+05                611811.0                 31545.0
# 1                      NaN                     NaN                     NaN
# 2             2.232875e+06               7637239.0                    92.0
# 3             1.260785e+05                343781.0                 83938.0
# 4             3.287153e+05               2955259.0                 64159.0
#
#    std_time_between_posts  var_time_between_posts  skw_time_between_posts  \
# 0            1.719894e+05            2.958036e+10                1.075537
# 1                     NaN                     NaN                     NaN
# 2            2.328249e+06            5.420744e+12                0.828757
# 3            8.045028e+04            6.472248e+09                1.596275
# 4            5.828985e+05            3.397707e+11                4.056672
#
#    real_account
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#
# [5 rows x 31 columns]

# %%
df_fake.head()
# Out:
#              username  profile_pic  biography  follows_count  \
# 0  _s.a.v.a__v.l.a.d_         True         56           2321
# 1     pp_sport_julduz         True        147           4247
# 2        clark5.7lyfe         True        127           1764
# 3           nata53149         True          0             68
# 4       olgashatko.63         True         80            242
#
#    followed_by_count  ff_ratio  media_count  is_private  is_verified  \
# 0                747  0.321844           10        True        False
# 1                611  0.143866           99       False        False
# 2               1613  0.914399           64       False        False
# 3                 65  0.955882            1       False        False
# 4                134  0.553719           80       False        False
#
#    is_business_account  ...  std_comments  var_comments  skw_comments  \
# 0                False  ...           NaN           NaN           NaN
# 1                 True  ...      0.678233      0.460000      2.068805
# 2                False  ...     10.224643    104.543333      3.196293
# 3                False  ...      0.000000      0.000000      0.000000
# 4                False  ...      0.624500      0.390000      4.086591
#
#    mean_time_between_posts  max_time_between_posts  min_time_between_posts  \
# 0                      NaN                     NaN                     NaN
# 1             80254.208333               1466742.0                    10.0
# 2            333885.000000                836121.0                 27637.0
# 3                 0.000000                     0.0                     0.0
# 4            694503.000000               6477346.0                     8.0
#
#    std_time_between_posts  var_time_between_posts  skw_time_between_posts  \
# 0                     NaN                     NaN                     NaN
# 1            2.973342e+05            8.840762e+10                4.488934
# 2            2.240602e+05            5.020299e+10                0.519589
# 3            0.000000e+00            0.000000e+00                0.000000
# 4            1.489132e+06            2.217513e+12                2.800966
#
#    real_account
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 31 columns]

# %% [markdown]
# # Analysis of number of Private Users in each Dataset (Real and Fake)

# %% [markdown]
# Below of every table it is possible to see the number of entries

# %%
df_real[df_real['is_private']==True]
# Out:
#                 username  profile_pic  biography  follows_count  \
# 1     dementieva_a______         True          0            423
# 9             carmenmb99         True         24           1032
# 10            msbritt319         True          0            605
# 15            ela.jiminx         True         21           1007
# 18        robert.tocilla         True         69            728
# ...                  ...          ...        ...            ...
# 7637            _gconti_         True         47           1281
# 7643   maffucci_lorenzo2         True          0            677
# 7644        88fuckinkeys         True         30            835
# 7650       silviabiscosi         True          0            662
# 7651         turco_luigi         True        147            902
#
#       followed_by_count  ff_ratio  media_count  is_private  is_verified  \
# 1                   192  0.453901           50        True        False
# 9                  1054  1.021318           98        True        False
# 10                  320  0.528926          174        True        False
# 15                  453  0.449851            8        True        False
# 18                  957  1.314560           18        True        False
# ...                 ...       ...          ...         ...          ...
# 7637               1088  0.849336          219        True        False
# 7643                393  0.580502           31        True        False
# 7644               1035  1.239521          257        True        False
# 7650                179  0.270393          232        True        False
# 7651               2602  2.884701          642        True        False
#
#       is_business_account  ...  std_comments  var_comments  skw_comments  \
# 1                   False  ...           NaN           NaN           NaN
# 9                   False  ...           NaN           NaN           NaN
# 10                  False  ...           NaN           NaN           NaN
# 15                  False  ...           NaN           NaN           NaN
# 18                  False  ...           NaN           NaN           NaN
# ...                   ...  ...           ...           ...           ...
# 7637                False  ...           NaN           NaN           NaN
# 7643                False  ...           NaN           NaN           NaN
# 7644                False  ...           NaN           NaN           NaN
# 7650                False  ...           NaN           NaN           NaN
# 7651                False  ...      2.314447      5.356667     -0.031184
#
#       mean_time_between_posts  max_time_between_posts  min_time_between_posts  \
# 1                         NaN                     NaN                     NaN
# 9                         NaN                     NaN                     NaN
# 10                        NaN                     NaN                     NaN
# 15                        NaN                     NaN                     NaN
# 18                        NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 7637                      NaN                     NaN                     NaN
# 7643                      NaN                     NaN                     NaN
# 7644                      NaN                     NaN                     NaN
# 7650                      NaN                     NaN                     NaN
# 7651            238850.333333                603786.0                 33387.0
#
#       std_time_between_posts  var_time_between_posts  skw_time_between_posts  \
# 1                        NaN                     NaN                     NaN
# 9                        NaN                     NaN                     NaN
# 10                       NaN                     NaN                     NaN
# 15                       NaN                     NaN                     NaN
# 18                       NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 7637                     NaN                     NaN                     NaN
# 7643                     NaN                     NaN                     NaN
# 7644                     NaN                     NaN                     NaN
# 7650                     NaN                     NaN                     NaN
# 7651           184874.369331            3.417853e+10                0.929054
#
#       real_account
# 1             True
# 9             True
# 10            True
# 15            True
# 18            True
# ...            ...
# 7637          True
# 7643          True
# 7644          True
# 7650          True
# 7651          True
#
# [1919 rows x 31 columns]

# %%
df_fake[df_fake['is_private']==True]
# Out:
#                 username  profile_pic  biography  follows_count  \
# 0     _s.a.v.a__v.l.a.d_         True         56           2321
# 14           hundalgeeta         True         33             19
# 19          dadi_borzooo        False         51           2782
# 25        itz_jonathan_1         True          0           2618
# 37            ana__chuma         True          0           1201
# ...                  ...          ...        ...            ...
# 7622         umari.insta         True         33            547
# 7627   priyanshthawariya         True          0            155
# 7638        andrestavlar         True         14           7077
# 7648    kristina_zhuchka         True         62            912
# 7649          tanku26_02         True         31           1440
#
#       followed_by_count  ff_ratio  media_count  is_private  is_verified  \
# 0                   747  0.321844           10        True        False
# 14                   26  1.368421            6        True        False
# 19                  706  0.253774            7        True        False
# 25                  323  0.123377            0        True        False
# 37                  405  0.337219           16        True        False
# ...                 ...       ...          ...         ...          ...
# 7622                322  0.588665            8        True        False
# 7627                139  0.896774            5        True        False
# 7638                899  0.127031           13        True        False
# 7648                945  1.036184          513        True        False
# 7649                504  0.350000           12        True        False
#
#       is_business_account  ...  std_comments  var_comments  skw_comments  \
# 0                   False  ...           NaN           NaN           NaN
# 14                  False  ...           NaN           NaN           NaN
# 19                  False  ...           NaN           NaN           NaN
# 25                  False  ...           NaN           NaN           NaN
# 37                  False  ...           NaN           NaN           NaN
# ...                   ...  ...           ...           ...           ...
# 7622                False  ...           NaN           NaN           NaN
# 7627                False  ...           NaN           NaN           NaN
# 7638                False  ...           NaN           NaN           NaN
# 7648                False  ...           NaN           NaN           NaN
# 7649                False  ...           NaN           NaN           NaN
#
#       mean_time_between_posts  max_time_between_posts  min_time_between_posts  \
# 0                         NaN                     NaN                     NaN
# 14                        NaN                     NaN                     NaN
# 19                        NaN                     NaN                     NaN
# 25                        NaN                     NaN                     NaN
# 37                        NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 7622                      NaN                     NaN                     NaN
# 7627                      NaN                     NaN                     NaN
# 7638                      NaN                     NaN                     NaN
# 7648                      NaN                     NaN                     NaN
# 7649                      NaN                     NaN                     NaN
#
#       std_time_between_posts  var_time_between_posts  skw_time_between_posts  \
# 0                        NaN                     NaN                     NaN
# 14                       NaN                     NaN                     NaN
# 19                       NaN                     NaN                     NaN
# 25                       NaN                     NaN                     NaN
# 37                       NaN                     NaN                     NaN
# ...                      ...                     ...                     ...
# 7622                     NaN                     NaN                     NaN
# 7627                     NaN                     NaN                     NaN
# 7638                     NaN                     NaN                     NaN
# 7648                     NaN                     NaN                     NaN
# 7649                     NaN                     NaN                     NaN
#
#       real_account
# 0            False
# 14           False
# 19           False
# 25           False
# 37           False
# ...            ...
# 7622         False
# 7627         False
# 7638         False
# 7648         False
# 7649         False
#
# [1026 rows x 31 columns]

# %% [markdown]
# # Creation of the Final Dataset merging the ones above

# %%
# Merging the dataset with real and fake users
df=pd.concat([df_real,df_fake],ignore_index=True)

# %% [markdown]
# # Fix the inconsistensy in the Dataset

# %% [markdown]
# In the project we had use two different scrapers for avoid the problem of the limited numbers of request from Instagram. The first scraper catch the users informations and the second one collect the media and compute the statistics. It is possible that sometimes between the two different times we used the two scraper some user switch from public to private. It's not possibile to get information from private users (it's a consistency problem) so the solution adopted is to switch the attribute private to public since when we collected the datas the users were public. It's also possible to switch to private and delete the statistic informations dropping additional infos that could be interesting and useful for the classification problem.

# %%
def fix_private_entries(dataset):
    dataset.loc[(dataset['is_private']==True)&(dataset['min_likes'].notnull()),['is_private']] = False
    return dataset

# %%
df.loc[df['is_private'] ==True]
# Out:
#                  username  profile_pic  biography  follows_count  \
# 1      dementieva_a______         True          0            423
# 9              carmenmb99         True         24           1032
# 10             msbritt319         True          0            605
# 15             ela.jiminx         True         21           1007
# 18         robert.tocilla         True         69            728
# ...                   ...          ...        ...            ...
# 15276         umari.insta         True         33            547
# 15281   priyanshthawariya         True          0            155
# 15292        andrestavlar         True         14           7077
# 15302    kristina_zhuchka         True         62            912
# 15303          tanku26_02         True         31           1440
#
#        followed_by_count  ff_ratio  media_count  is_private  is_verified  \
# 1                    192  0.453901           50        True        False
# 9                   1054  1.021318           98        True        False
# 10                   320  0.528926          174        True        False
# 15                   453  0.449851            8        True        False
# 18                   957  1.314560           18        True        False
# ...                  ...       ...          ...         ...          ...
# 15276                322  0.588665            8        True        False
# 15281                139  0.896774            5        True        False
# 15292                899  0.127031           13        True        False
# 15302                945  1.036184          513        True        False
# 15303                504  0.350000           12        True        False
#
#        is_business_account  ...  std_comments  var_comments  skw_comments  \
# 1                    False  ...           NaN           NaN           NaN
# 9                    False  ...           NaN           NaN           NaN
# 10                   False  ...           NaN           NaN           NaN
# 15                   False  ...           NaN           NaN           NaN
# 18                   False  ...           NaN           NaN           NaN
# ...                    ...  ...           ...           ...           ...
# 15276                False  ...           NaN           NaN           NaN
# 15281                False  ...           NaN           NaN           NaN
# 15292                False  ...           NaN           NaN           NaN
# 15302                False  ...           NaN           NaN           NaN
# 15303                False  ...           NaN           NaN           NaN
#
#        mean_time_between_posts  max_time_between_posts  \
# 1                          NaN                     NaN
# 9                          NaN                     NaN
# 10                         NaN                     NaN
# 15                         NaN                     NaN
# 18                         NaN                     NaN
# ...                        ...                     ...
# 15276                      NaN                     NaN
# 15281                      NaN                     NaN
# 15292                      NaN                     NaN
# 15302                      NaN                     NaN
# 15303                      NaN                     NaN
#
#        min_time_between_posts  std_time_between_posts  var_time_between_posts  \
# 1                         NaN                     NaN                     NaN
# 9                         NaN                     NaN                     NaN
# 10                        NaN                     NaN                     NaN
# 15                        NaN                     NaN                     NaN
# 18                        NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 15276                     NaN                     NaN                     NaN
# 15281                     NaN                     NaN                     NaN
# 15292                     NaN                     NaN                     NaN
# 15302                     NaN                     NaN                     NaN
# 15303                     NaN                     NaN                     NaN
#
#        skw_time_between_posts  real_account
# 1                         NaN          True
# 9                         NaN          True
# 10                        NaN          True
# 15                        NaN          True
# 18                        NaN          True
# ...                       ...           ...
# 15276                     NaN         False
# 15281                     NaN         False
# 15292                     NaN         False
# 15302                     NaN         False
# 15303                     NaN         False
#
# [2945 rows x 31 columns]

# %%
df.loc[(df['is_private'] ==True)&(df['min_likes'].notnull())]
# Out:
#                             username  profile_pic  biography  follows_count  \
# 257                       giuliacann         True         61           1113
# 260                     ellensynlove         True          0            530
# 1196                        nerepast         True        135            520
# 1696                       giorgi_10         True          2            669
# 1753                 movimento5litri         True        123             81
# 2068                   _dilettacioni         True          0            354
# 2448                   peg_alexander         True         80           2864
# 2487                         rava.41         True         43            314
# 2494                carloshernandz23         True         21            952
# 2676                        jero.rod         True          7            379
# 2775                michele.marchesi         True         40            490
# 3114                  giuliadalcanto         True         89           2082
# 3222           maxfelicitas.official         True         82              0
# 3336                     elisaurora7         True         81            694
# 3903    ____agnieszka_malgorzata____         True        100            953
# 4427                        sa.fedri         True         41            936
# 4749                  jovanova______         True         20           6794
# 4858                         ilgasbe         True         85           4197
# 5012                        dar.riar         True          0            475
# 5042               thefrenchtoast_lr         True        126           1540
# 5278                    ghetto_trash         True        105            173
# 5328                       _seba218_         True         60            353
# 5345                 danielecampione         True        129           1071
# 5391                        malo_vbt         True        128            661
# 5687                     cosenoncose         True         57             40
# 5993                katerinatalashko         True          0            208
# 6286                       jocener31         True         45            801
# 6425                 gretagarigliani         True          0            751
# 6521                 chiarafranconii         True          4            375
# 6650                  20_maria_20_20         True         64           2039
# 6746                    chiara_mac17         True        147           1567
# 6782                fraaancescarusso         True         70            831
# 6813                  memes._.world_         True        114            198
# 6927                   pablo_guindii         True         47           1011
# 7021                 lenanarivonchik         True          0            228
# 7447                     anidochkadi         True          0            358
# 7651                     turco_luigi         True        147            902
# 7901                        _x_a_m._         True        106           5971
# 8214                  olgadepilation         True        142            887
# 8361                       l20aishal         True          0            123
# 8454   islamskaya_aptechka_al_kausar         True         38           1715
# 8643                0mironova_dasha0         True          0            648
# 9255                 7_harutyunyan_7         True          3            323
# 9849                 danielbest3._.2        False        132           1789
# 10322                      iri___ska         True          0            193
# 10739                   marko_qsimic         True          2            870
# 10920                 gaytukiev_oo1_         True         73            277
# 11207                    zakroemzaim         True        122           7446
# 11260              diiimpleface.raee         True         78           1160
# 11627                    envy_junior         True         78           5887
# 12033                  __.dimon4ik__         True         66           5207
# 12080                       ash_779_         True          0           1515
# 12107                 louise_gwaneza         True        100             42
# 12742                 katrin_style85         True        144           3901
# 12774                     chesneyrxe         True         60           5847
# 15078                     adel_eclot         True        150           3916
#
#        followed_by_count       ff_ratio  media_count  is_private  is_verified  \
# 257                  628       0.564241          555        True        False
# 260                  494       0.932075          109        True        False
# 1196                 563       1.082692           94        True        False
# 1696                 888       1.327354          639        True        False
# 1753             1465587   18093.666667         8552        True        False
# 2068                 890       2.514124           24        True        False
# 2448                5055       1.765014           85        True        False
# 2487                 291       0.926752          101        True        False
# 2494                1441       1.513655           22        True        False
# 2676                1205       3.179420           49        True        False
# 2775                 696       1.420408          361        True        False
# 3114                6546       3.144092          249        True        False
# 3222              468953  468953.000000          153        True         True
# 3336                 933       1.344380          304        True        False
# 3903                 626       0.656873          101        True        False
# 4427                 502       0.536325          273        True        False
# 4749               10687       1.573006          326        True        False
# 4858                3302       0.786752          183        True        False
# 5012                 501       1.054737           47        True        False
# 5042                 961       0.624026         1538        True        False
# 5278              440927    2548.710983         3975        True        False
# 5328                1683       4.767705          492        True        False
# 5345                1765       1.647993          223        True        False
# 5391                 263       0.397882            2        True        False
# 5687              631653   15791.325000         3466        True        False
# 5993                  87       0.418269           15        True        False
# 6286                 240       0.299625           71        True        False
# 6425                 931       1.239680          537        True        False
# 6521                 588       1.568000          126        True        False
# 6650                 338       0.165768          127        True        False
# 6746                1014       0.647096          124        True        False
# 6782                1121       1.348977          295        True        False
# 6813               79655     402.297980         1524        True        False
# 6927                1164       1.151335           22        True        False
# 7021                  93       0.407895           47        True        False
# 7447                 485       1.354749           11        True        False
# 7651                2602       2.884701          642        True        False
# 7901                1584       0.265282           17        True        False
# 8214                 307       0.346110           12        True        False
# 8361                  42       0.341463            9        True        False
# 8454                 442       0.257726           29        True        False
# 8643                 224       0.345679           17        True        False
# 9255                 278       0.860681            1        True        False
# 9849                 599       0.334824            5        True        False
# 10322                128       0.663212          134        True        False
# 10739               1923       2.210345            1        True        False
# 10920               2183       7.880866            3        True        False
# 11207               3301       0.443325           66        True        False
# 11260                333       0.287069            0        True        False
# 11627               3428       0.582300            3        True        False
# 12033               1195       0.229499            8        True        False
# 12080                341       0.225083            6        True        False
# 12107                357       8.500000           11        True        False
# 12742               2727       0.699052          997        True        False
# 12774               3579       0.612109           24        True        False
# 15078               1607       0.410368          859        True        False
#
#        is_business_account  ...  std_comments  var_comments  skw_comments  \
# 257                  False  ...      1.339154  1.793333e+00      0.430254
# 260                  False  ...      1.691153  2.860000e+00      3.198243
# 1196                 False  ...      4.148494  1.721000e+01      3.001120
# 1696                 False  ...      2.573584  6.623333e+00      1.002724
# 1753                 False  ...   4229.990925  1.789282e+07      4.627252
# 2068                 False  ...      1.190999  1.418478e+00      1.017891
# 2448                 False  ...      1.598958  2.556667e+00      2.105953
# 2487                 False  ...      0.957427  9.166667e-01      1.453641
# 2494                 False  ...     14.477205  2.095895e+02      2.894582
# 2676                 False  ...     12.030932  1.447433e+02      0.359220
# 2775                 False  ...      4.031956  1.625667e+01      0.931758
# 3114                 False  ...     14.857994  2.207600e+02      1.516364
# 3222                 False  ...    981.486945  9.633166e+05      1.464644
# 3336                 False  ...      1.423610  2.026667e+00      1.364184
# 3903                 False  ...      1.997498  3.990000e+00      1.026663
# 4427                 False  ...      1.707825  2.916667e+00      0.891299
# 4749                 False  ...      2.580698  6.660000e+00      1.275781
# 4858                 False  ...      1.164760  1.356667e+00      0.651568
# 5012                 False  ...      2.118962  4.490000e+00      1.633484
# 5042                 False  ...      1.732051  3.000000e+00      3.682848
# 5278                 False  ...    221.871772  4.922708e+04      2.457111
# 5328                 False  ...     19.979323  3.991733e+02      1.573629
# 5345                 False  ...      3.539303  1.252667e+01      1.470685
# 5391                 False  ...      6.000000  3.600000e+01      0.000000
# 5687                 False  ...    280.843652  7.887316e+04      3.628704
# 5993                 False  ...      1.083625  1.174242e+00      1.062322
# 6286                 False  ...      3.643259  1.327333e+01      2.196468
# 6425                 False  ...      2.208318  4.876667e+00      0.869286
# 6521                 False  ...      3.752777  1.408333e+01      0.699061
# 6650                 False  ...      0.472582  2.233333e-01      2.951336
# 6746                 False  ...      8.883130  7.891000e+01      3.607127
# 6782                 False  ...      1.508863  2.276667e+00      0.907251
# 6813                 False  ...     20.938561  4.384233e+02      2.255061
# 6927                 False  ...      6.695123  4.482468e+01      1.868299
# 7021                 False  ...      2.081666  4.333333e+00      3.422604
# 7447                 False  ...      3.424511  1.172727e+01      1.482428
# 7651                 False  ...      2.314447  5.356667e+00     -0.031184
# 7901                 False  ...      3.124137  9.760234e+00      1.576205
# 8214                 False  ...      0.900337  8.106061e-01      2.209942
# 8361                 False  ...      0.646670  4.181818e-01      2.077008
# 8454                 False  ...      1.695091  2.873333e+00      1.792314
# 8643                 False  ...      2.373258  5.632353e+00      2.764074
# 9255                 False  ...      0.000000  0.000000e+00      0.000000
# 9849                 False  ...      3.214550  1.033333e+01      0.630904
# 10322                False  ...      0.276887  7.666667e-02      3.096281
# 10739                False  ...      0.000000  0.000000e+00      0.000000
# 10920                False  ...     19.986662  3.994667e+02      0.922938
# 11207                False  ...      0.600000  3.600000e-01      4.694855
# 11260                False  ...      3.535534  1.250000e+01      0.000000
# 11627                False  ...      3.535534  1.250000e+01      0.000000
# 12033                False  ...      5.147815  2.650000e+01      1.557522
# 12080                False  ...      1.601282  2.564103e+00      0.777000
# 12107                False  ...      2.695896  7.267857e+00      1.637576
# 12742                False  ...      0.200000  4.000000e-02      4.694855
# 12774                False  ...      4.144142  1.717391e+01      1.684412
# 15078                False  ...      0.000000  0.000000e+00      0.000000
#
#        mean_time_between_posts  max_time_between_posts  \
# 257               3.383401e+05               1035596.0
# 260               1.029883e+06               4314974.0
# 1196              5.711074e+05               2197674.0
# 1696              4.384995e+05               4035110.0
# 1753              2.152875e+04                 60477.0
# 2068              2.874744e+06              18726342.0
# 2448              1.515798e+06               9251686.0
# 2487              4.121823e+06              12777378.0
# 2494              5.064787e+06              17432517.0
# 2676              3.430008e+06              12432499.0
# 2775              7.120626e+05               1811723.0
# 3114              5.305289e+05               1841059.0
# 3222              1.058630e+06               2503051.0
# 3336              4.181502e+05               1853746.0
# 3903              2.802345e+05               1185088.0
# 4427              4.818757e+05               2365291.0
# 4749              9.147828e+05               3030054.0
# 4858              8.404168e+05               1792583.0
# 5012              3.009957e+05               1124416.0
# 5042              1.804403e+05                778672.0
# 5278              1.466558e+04                 55626.0
# 5328              1.465247e+06              13550111.0
# 5345              3.591814e+06              17457018.0
# 5391              1.468590e+06               1729097.0
# 5687              7.392458e+03                 47193.0
# 5993              1.427749e+06              11029128.0
# 6286              1.339008e+06              13756552.0
# 6425              1.644710e+06              11925088.0
# 6521              3.648195e+06              13257047.0
# 6650              3.520043e+05               5810554.0
# 6746              3.764922e+05               1985024.0
# 6782              8.239032e+05               3003410.0
# 6813              5.843446e+04                162763.0
# 6927              2.073262e+06               6649680.0
# 7021              1.895593e+06               7423845.0
# 7447              5.360534e+06              17715282.0
# 7651              2.388503e+05                603786.0
# 7901              3.040886e+05               2322332.0
# 8214              2.276032e+06               7412448.0
# 8361              3.494561e+05               1489119.0
# 8454              2.100135e+05               1984795.0
# 8643              1.801214e+06               3889855.0
# 9255              0.000000e+00                     0.0
# 9849              3.576515e+06               5015522.0
# 10322             4.061081e+05               2064752.0
# 10739             7.819297e+05               4349123.0
# 10920             7.522777e+06              33036219.0
# 11207             3.493317e+04                144938.0
# 11260             2.253390e+05                225339.0
# 11627             3.881496e+06               3881496.0
# 12033             1.324312e+06               2342134.0
# 12080             1.147215e+06               9605981.0
# 12107             7.260506e+05               2166475.0
# 12742             3.932488e+04                363787.0
# 12774             1.158483e+06               5170503.0
# 15078             2.792333e+03                 47269.0
#
#        min_time_between_posts  std_time_between_posts  var_time_between_posts  \
# 257                   33293.0            2.100937e+05            4.413938e+10
# 260                     864.0            1.241301e+06            1.540829e+12
# 1196                    302.0            6.950057e+05            4.830330e+11
# 1696                    476.0            9.117011e+05            8.311990e+11
# 1753                   4397.0            2.077920e+04            4.317750e+08
# 2068                  96289.0            4.172031e+06            1.740584e+13
# 2448                     23.0            2.618323e+06            6.855614e+12
# 2487                 255191.0            3.531217e+06            1.246950e+13
# 2494                 106689.0            5.551776e+06            3.082221e+13
# 2676                 343312.0            2.956376e+06            8.740159e+12
# 2775                 143689.0            5.468826e+05            2.990805e+11
# 3114                   1626.0            6.735562e+05            4.536780e+11
# 3222                  80387.0            7.091184e+05            5.028489e+11
# 3336                  25800.0            3.937302e+05            1.550235e+11
# 3903                    112.0            2.944434e+05            8.669695e+10
# 4427                  66095.0            5.978067e+05            3.573728e+11
# 4749                  31323.0            8.335229e+05            6.947604e+11
# 4858                 117098.0            4.009773e+05            1.607828e+11
# 5012                    108.0            3.124436e+05            9.762100e+10
# 5042                   2469.0            1.599727e+05            2.559127e+10
# 5278                    945.0            1.611870e+04            2.598124e+08
# 5328                  85677.0            2.668473e+06            7.120749e+12
# 5345                 270020.0            4.255636e+06            1.811044e+13
# 5391                1208084.0            3.684118e+05            1.357273e+11
# 5687                   1476.0            9.727521e+03            9.462466e+07
# 5993                  16689.0            3.233217e+06            1.045369e+13
# 6286                     35.0            3.547493e+06            1.258471e+13
# 6425                 114810.0            2.558489e+06            6.545864e+12
# 6521                  75913.0            3.729993e+06            1.391285e+13
# 6650                     44.0            1.259476e+06            1.586280e+12
# 6746                    451.0            4.977953e+05            2.478002e+11
# 6782                 162631.0            7.386990e+05            5.456763e+11
# 6813                    697.0            5.368829e+04            2.882433e+09
# 6927                 174630.0            1.611430e+06            2.596705e+12
# 7021                     10.0            2.083936e+06            4.342790e+12
# 7447                 243622.0            5.894483e+06            3.474493e+13
# 7651                  33387.0            1.848744e+05            3.417853e+10
# 7901                     24.0            5.778855e+05            3.339517e+11
# 8214                   3349.0            3.183989e+06            1.013779e+13
# 8361                     10.0            5.112816e+05            2.614089e+11
# 8454                    525.0            4.274775e+05            1.827370e+11
# 8643                  63279.0            1.345926e+06            1.811516e+12
# 9255                      0.0            0.000000e+00            0.000000e+00
# 9849                2137508.0            2.035063e+06            4.141482e+12
# 10322                    48.0            5.041802e+05            2.541977e+11
# 10739                    21.0            1.752908e+06            3.072687e+12
# 10920                   297.0            1.431520e+07            2.049250e+14
# 11207                    12.0            4.742033e+04            2.248688e+09
# 11260                225339.0            0.000000e+00            0.000000e+00
# 11627               3881496.0            0.000000e+00            0.000000e+00
# 12033                    99.0            8.691984e+05            7.555058e+11
# 12080                    21.0            2.719059e+06            7.393280e+12
# 12107                187456.0            6.833577e+05            4.669778e+11
# 12742                    84.0            9.889766e+04            9.780747e+09
# 12774                 88226.0            1.407947e+06            1.982315e+12
# 15078                    32.0            9.684331e+03            9.378627e+07
#
#        skw_time_between_posts  real_account
# 257                  1.591702          True
# 260                  1.462782          True
# 1196                 1.266380          True
# 1696                 3.035207          True
# 1753                 1.070064          True
# 2068                 2.665449          True
# 2448                 1.845048          True
# 2487                 0.983721          True
# 2494                 1.162411          True
# 2676                 1.436364          True
# 2775                 0.625162          True
# 3114                 0.946825          True
# 3222                 0.484967          True
# 3336                 2.302790          True
# 3903                 1.386961          True
# 4427                 2.291749          True
# 4749                 1.124957          True
# 4858                 0.168065          True
# 5012                 1.293243          True
# 5042                 2.244401          True
# 5278                 1.584894          True
# 5328                 4.110943          True
# 5345                 1.938437          True
# 5391                 0.000000          True
# 5687                 3.239454          True
# 5993                 2.697486          True
# 6286                 2.914594          True
# 6425                 2.993339          True
# 6521                 1.362470          True
# 6650                 3.780921          True
# 6746                 2.145646          True
# 6782                 1.402957          True
# 6813                 0.656763          True
# 6927                 1.377332          True
# 7021                 1.426538          True
# 7447                 1.069970          True
# 7651                 0.929054          True
# 7901                 2.621431         False
# 8214                 0.972495         False
# 8361                 1.288320         False
# 8454                 3.234023         False
# 8643                 0.220887         False
# 9255                 0.000000         False
# 9849                 0.000000         False
# 10322                1.737748         False
# 10739                1.765166         False
# 10920                1.472863         False
# 11207                1.120346         False
# 11260                0.000000         False
# 11627                0.000000         False
# 12033               -0.310981         False
# 12080                2.815642         False
# 12107                1.499600         False
# 12742                2.782947         False
# 12774                1.799975         False
# 15078                4.291027         False
#
# [56 rows x 31 columns]

# %%
#Fixing the entries with private users (for scraping errors)
df=fix_private_entries(df)

# %%
# Fix the dataset with incorrect entries
df.loc[(df['is_private'] ==True)&(df['min_likes'].notnull())]
# Out:
# Empty DataFrame
# Columns: [username, profile_pic, biography, follows_count, followed_by_count, ff_ratio, media_count, is_private, is_verified, is_business_account, is_joined_recently, highlight_reel_count, average_likes, max_likes, min_likes, std_likes, var_likes, skw_likes, average_comments, max_comments, min_comments, std_comments, var_comments, skw_comments, mean_time_between_posts, max_time_between_posts, min_time_between_posts, std_time_between_posts, var_time_between_posts, skw_time_between_posts, real_account]
# Index: []
#
# [0 rows x 31 columns]

# %%
features_columns=list(df.columns[:30])
# targets_column=list(df.columns[30:31])
print(features_columns)
# Out:
# ['username', 'profile_pic', 'biography', 'follows_count', 'followed_by_count', 'ff_ratio', 'media_count', 'is_private', 'is_verified', 'is_business_account', 'is_joined_recently', 'highlight_reel_count', 'average_likes', 'max_likes', 'min_likes', 'std_likes', 'var_likes', 'skw_likes', 'average_comments', 'max_comments', 'min_comments', 'std_comments', 'var_comments', 'skw_comments', 'mean_time_between_posts', 'max_time_between_posts', 'min_time_between_posts', 'std_time_between_posts', 'var_time_between_posts', 'skw_time_between_posts']

# %%
df.shape
# Out:
# (15308, 31)

# %%
targets = df['real_account'].values
df=df.loc[:,'profile_pic':'skw_time_between_posts']

# %%
targets
# Out:
# array([ True,  True,  True, ..., False, False, False])
