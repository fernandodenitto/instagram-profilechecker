# %%
import pandas as pd
#Carico il dataset 
dataset=pd.read_csv("data_fake.csv")

# %%
print(dataset)
# Out:
#       profile_pic  biography  follows_count  followed_by_count  ff_ratio  \
# 0            True       True           2321                747  0.321705
# 1            True       True           4247                611  0.143832
# 2            True       True            781                338  0.432225
# 3            True       True           1764               1613  0.913881
# 4            True      False             68                 65  0.942029
# ...           ...        ...            ...                ...       ...
# 7837         True       True           2323                 72  0.030981
# 7838         True       True           2311               2934  1.269031
# 7839         True       True           7498               2340  0.312042
# 7840         True      False           6321                327  0.051724
# 7841         True       True           6531                 61  0.009339
#
#       media_count  is_private  is_verified  is_business_account  \
# ...

# %%
dataset.head()
# Out:
#    profile_pic  biography  follows_count  followed_by_count  ff_ratio  \
# 0         True       True           2321                747  0.321705
# 1         True       True           4247                611  0.143832
# 2         True       True            781                338  0.432225
# 3         True       True           1764               1613  0.913881
# 4         True      False             68                 65  0.942029
#
#    media_count  is_private  is_verified  is_business_account  \
# 0           10        True        False                False
# 1           99       False        False                 True
# 2          128        True        False                False
# 3           64       False        False                False
# 4            1       False        False                False
#
#    is_joined_recently  ...  std_comments  var_comments  skw_comments  \
# 0               False  ...           NaN           NaN           NaN
# ...

# %%
dataset.describe()
# Out:
#        follows_count  followed_by_count     ff_ratio   media_count  \
# count    7842.000000        7842.000000  7842.000000   7842.000000
# mean     3011.887656         878.089135     0.643426    131.099847
# std      2643.689645        3544.808749     3.223561   1046.948988
# min         1.000000           0.000000     0.000000      0.000000
# 25%       470.250000          61.000000     0.018172      3.000000
# 50%      2163.500000         161.500000     0.261928     11.000000
# 75%      5874.000000         691.750000     0.623896     54.000000
# max      7551.000000      162061.000000   210.375000  76286.000000
#
#        highlight_reel_count  average_likes     max_likes    min_likes  \
# count           7842.000000    5531.000000   5531.000000  5531.000000
# mean               1.784494      42.802532     92.506780    20.891340
# std                7.532981     119.825723    282.938346    62.876551
# min                0.000000       0.000000      0.000000     0.000000
# ...
