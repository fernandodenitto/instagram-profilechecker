# %% [markdown]
# # KNN Classification with NaN Handling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler

# %%
df_real = pd.read_csv('../data/data_real.csv')
df_fake = pd.read_csv('../data/data_fake.csv')

# %%
df_real.head()
# Out:
#    profile_pic  biography  follows_count  followed_by_count  ff_ratio  \
# 0         True      False           1128                575  0.509300
# 1         True       True            430                353  0.819026
# 2         True       True            418                534  1.274463
# 3         True       True           1425               3118  2.186536
# 4         True       True            953                288  0.301887
#
#    media_count  is_private  is_verified  is_business_account  \
# 0          322       False        False                False
# 1            3       False        False                 True
# 2          139       False        False                False
# 3          206       False        False                 True
# 4          458        True        False                False
#
#    is_joined_recently  ...  std_comments  var_comments  skw_comments  \
# 0               False  ...      1.527525      2.333333      1.131088
# 1               False  ...      9.237604     85.333333      0.707107
# 2               False  ...      7.131620     50.860000      0.321661
# 3               False  ...     11.146449    124.243333      0.682247
# 4               False  ...           NaN           NaN           NaN
#
#    mean_time_between_posts  max_time_between_posts  min_time_between_posts  \
# 0             1.491866e+06               7517421.0                     5.0
# 1             5.472764e+06               6023604.0               4921924.0
# 2             3.611337e+06              10774210.0                164203.0
# 3             1.338888e+06               4057835.0                233556.0
# 4                      NaN                     NaN                     NaN
#
#    std_time_between_posts  var_time_between_posts  skw_time_between_posts  \
# 0            1.832700e+06            3.358789e+12                1.797422
# 1            7.790054e+05            6.068494e+11                0.000000
# 2            3.163705e+06            1.000903e+13                1.065019
# 3            1.025556e+06            1.051766e+12                0.939111
# 4                     NaN                     NaN                     NaN
#
#    real_account
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#
# [5 rows x 31 columns]

# %%
df_fake.head()
# Out:
#    profile_pic  biography  follows_count  followed_by_count  ff_ratio  \
# 0         True       True           2321                747  0.321705
# 1         True       True           4247                611  0.143832
# 2         True       True            781                338  0.432225
# 3         True       True           1764               1613  0.913881
# 4         True      False             68                 65  0.942029
#
#    media_count  is_private  is_verified  is_business_account  \
# 0           10        True        False                False
# 1           99       False        False                 True
# 2          128        True        False                False
# 3           64       False        False                False
# 4            1       False        False                False
#
#    is_joined_recently  ...  std_comments  var_comments  skw_comments  \
# 0               False  ...           NaN           NaN           NaN
# 1               False  ...           NaN           NaN           NaN
# 2               False  ...           NaN           NaN           NaN
# 3               False  ...           NaN           NaN           NaN
# 4               False  ...           NaN           NaN           NaN
#
#    mean_time_between_posts  max_time_between_posts  min_time_between_posts  \
# 0                      NaN                     NaN                     NaN
# 1                      NaN                     NaN                     NaN
# 2                      NaN                     NaN                     NaN
# 3                      NaN                     NaN                     NaN
# 4                      NaN                     NaN                     NaN
#
#    std_time_between_posts  var_time_between_posts  skw_time_between_posts  \
# 0                     NaN                     NaN                     NaN
# 1                     NaN                     NaN                     NaN
# 2                     NaN                     NaN                     NaN
# 3                     NaN                     NaN                     NaN
# 4                     NaN                     NaN                     NaN
#
#    real_account
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 31 columns]

# %%
# df_real.fillna(df_real.mean(),inplace=True)
# df_fake.fillna(df_fake.mean(),inplace=True)
df_fake.head()
# Out:
#    profile_pic  biography  follows_count  followed_by_count  ff_ratio  \
# 0         True       True           2321                747  0.321705
# 1         True       True           4247                611  0.143832
# 2         True       True            781                338  0.432225
# 3         True       True           1764               1613  0.913881
# 4         True      False             68                 65  0.942029
#
#    media_count  is_private  is_verified  is_business_account  \
# 0           10        True        False                False
# 1           99       False        False                 True
# 2          128        True        False                False
# 3           64       False        False                False
# 4            1       False        False                False
#
#    is_joined_recently  ...  std_comments  var_comments  skw_comments  \
# 0               False  ...      3.655663    907.748635      1.407236
# 1               False  ...      3.655663    907.748635      1.407236
# 2               False  ...      3.655663    907.748635      1.407236
# 3               False  ...      3.655663    907.748635      1.407236
# 4               False  ...      3.655663    907.748635      1.407236
#
#    mean_time_between_posts  max_time_between_posts  min_time_between_posts  \
# 0             1.448237e+06            6.416945e+06           365352.982407
# 1             1.448237e+06            6.416945e+06           365352.982407
# 2             1.448237e+06            6.416945e+06           365352.982407
# 3             1.448237e+06            6.416945e+06           365352.982407
# 4             1.448237e+06            6.416945e+06           365352.982407
#
#    std_time_between_posts  var_time_between_posts  skw_time_between_posts  \
# 0            2.026147e+06            2.566560e+13                1.676456
# 1            2.026147e+06            2.566560e+13                1.676456
# 2            2.026147e+06            2.566560e+13                1.676456
# 3            2.026147e+06            2.566560e+13                1.676456
# 4            2.026147e+06            2.566560e+13                1.676456
#
#    real_account
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#
# [5 rows x 31 columns]

# %%
df=pd.concat([df_real,df_fake],ignore_index=True)

# %%
print(df)
# Out:
#        profile_pic  biography  follows_count  followed_by_count  ff_ratio  \
# 0             True      False           1128                575  0.509300
# 1             True       True            430                353  0.819026
# 2             True       True            418                534  1.274463
# 3             True       True           1425               3118  2.186536
# 4             True       True            953                288  0.301887
# ...            ...        ...            ...                ...       ...
# 17482         True       True           2323                 72  0.030981
# 17483         True       True           2311               2934  1.269031
# 17484         True       True           7498               2340  0.312042
# 17485         True      False           6321                327  0.051724
# 17486         True       True           6531                 61  0.009339
#
#        media_count  is_private  is_verified  is_business_account  \
# 0              322       False        False                False
# 1                3       False        False                 True
# 2              139       False        False                False
# 3              206       False        False                 True
# 4              458        True        False                False
# ...            ...         ...          ...                  ...
# 17482           20       False        False                False
# 17483           55       False        False                False
# 17484           39       False        False                 True
# 17485           15       False        False                False
# 17486            7       False        False                False
#
#        is_joined_recently  ...  std_comments  var_comments  skw_comments  \
# 0                   False  ...      1.527525  2.333333e+00      1.131088
# 1                   False  ...      9.237604  8.533333e+01      0.707107
# 2                   False  ...      7.131620  5.086000e+01      0.321661
# 3                   False  ...     11.146449  1.242433e+02      0.682247
# 4                   False  ...    225.148842  7.611672e+06      1.640635
# ...                   ...  ...           ...           ...           ...
# 17482               False  ...      6.340347  4.020000e+01      1.582760
# 17483               False  ...      0.472582  2.233333e-01      2.951336
# 17484               False  ...      3.329164  1.108333e+01      0.677680
# 17485               False  ...      2.313521  5.352381e+00      2.028695
# 17486               False  ...      0.000000  0.000000e+00      0.000000
#
#        mean_time_between_posts  max_time_between_posts  \
# 0                 1.491866e+06            7.517421e+06
# 1                 5.472764e+06            6.023604e+06
# 2                 3.611337e+06            1.077421e+07
# 3                 1.338888e+06            4.057835e+06
# 4                 1.334810e+06            6.572650e+06
# ...                        ...                     ...
# 17482             2.975948e+05            2.685349e+06
# 17483             6.898008e+05            6.434047e+06
# 17484             9.702668e+05            3.269496e+06
# 17485             3.078766e+06            1.686083e+07
# 17486             8.326883e+05            1.910995e+06
#
#        min_time_between_posts  std_time_between_posts  var_time_between_posts  \
# 0                5.000000e+00            1.832700e+06            3.358789e+12
# 1                4.921924e+06            7.790054e+05            6.068494e+11
# 2                1.642030e+05            3.163705e+06            1.000903e+13
# 3                2.335560e+05            1.025556e+06            1.051766e+12
# 4                1.278859e+05            1.729140e+06            1.514431e+13
# ...                       ...                     ...                     ...
# 17482            2.300000e+01            7.634178e+05            5.828067e+11
# 17483            1.380000e+02            1.780056e+06            3.168601e+12
# 17484            2.800000e+02            7.913546e+05            6.262421e+11
# 17485            1.000000e+01            5.588747e+06            3.123409e+13
# 17486            5.223830e+05            5.305299e+05            2.814620e+11
#
#        skw_time_between_posts  real_account
# 0                    1.797422          True
# 1                    0.000000          True
# 2                    1.065019          True
# 3                    0.939111          True
# 4                    1.656720          True
# ...                       ...           ...
# 17482                2.578928         False
# 17483                2.400901         False
# 17484                1.132687         False
# 17485                1.579750         False
# 17486                1.753490         False
#
# [17487 rows x 31 columns]

# %%
features_columns=list(df.columns[:30])
# targets_column=list(df.columns[30:31])
# df.head()
print(features_columns)
# Out:
# ['profile_pic', 'biography', 'follows_count', 'followed_by_count', 'ff_ratio', 'media_count', 'is_private', 'is_verified', 'is_business_account', 'is_joined_recently', 'highlight_reel_count', 'connected_fb_page', 'average_likes', 'max_likes', 'min_likes', 'std_likes', 'var_likes', 'skw_likes', 'average_comments', 'max_comments', 'min_comments', 'std_comments', 'var_comments', 'skw_comments', 'mean_time_between_posts', 'max_time_between_posts', 'min_time_between_posts', 'std_time_between_posts', 'var_time_between_posts', 'skw_time_between_posts']

# %%
df.shape
# Out:
# (17487, 31)

# %%
targets = df['real_account'].values
# df=df.loc[:,'profile_pic':'highlight_reel_count']

# %%
targets
# Out:
# array([ True,  True,  True, ..., False, False, False])

# %%
# df.drop('real_account', axis=1, inplace=True)

# %%
df.head()
# Out:
#    profile_pic  biography  follows_count  followed_by_count  ff_ratio  \
# 0         True      False           1128                575  0.509300
# 1         True       True            430                353  0.819026
# 2         True       True            418                534  1.274463
# 3         True       True           1425               3118  2.186536
# 4         True       True            953                288  0.301887
#
#    media_count  is_private  is_verified  is_business_account  \
# 0          322       False        False                False
# 1            3       False        False                 True
# 2          139       False        False                False
# 3          206       False        False                 True
# 4          458        True        False                False
#
#    is_joined_recently  ...  std_comments  var_comments  skw_comments  \
# 0               False  ...      1.527525  2.333333e+00      1.131088
# 1               False  ...      9.237604  8.533333e+01      0.707107
# 2               False  ...      7.131620  5.086000e+01      0.321661
# 3               False  ...     11.146449  1.242433e+02      0.682247
# 4               False  ...    225.148842  7.611672e+06      1.640635
#
#    mean_time_between_posts  max_time_between_posts  min_time_between_posts  \
# 0             1.491866e+06            7.517421e+06            5.000000e+00
# 1             5.472764e+06            6.023604e+06            4.921924e+06
# 2             3.611337e+06            1.077421e+07            1.642030e+05
# 3             1.338888e+06            4.057835e+06            2.335560e+05
# 4             1.334810e+06            6.572650e+06            1.278859e+05
#
#    std_time_between_posts  var_time_between_posts  skw_time_between_posts  \
# 0            1.832700e+06            3.358789e+12                1.797422
# 1            7.790054e+05            6.068494e+11                0.000000
# 2            3.163705e+06            1.000903e+13                1.065019
# 3            1.025556e+06            1.051766e+12                0.939111
# 4            1.729140e+06            1.514431e+13                1.656720
#
#    real_account
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#
# [5 rows x 31 columns]

# %%
df_sc = StandardScaler().fit_transform(df)

# %%
x_train, x_test, y_train, y_test = train_test_split(df_sc, targets, test_size = 0.2, random_state = 12345)

# %%
knn = KNeighborsClassifier()

# %%
knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
knn_pred = knn.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# %%
print(confusion_matrix(y_test, knn_pred))
# Out:
# [[1623    7]
#  [   4 1864]]

# %%
print(classification_report(y_test, knn_pred))
# Out:
#               precision    recall  f1-score   support
#
#        False       1.00      1.00      1.00      1630
#         True       1.00      1.00      1.00      1868
#
#     accuracy                           1.00      3498
#    macro avg       1.00      1.00      1.00      3498
# weighted avg       1.00      1.00      1.00      3498

# %%
err = []

for i in range(1, 30):
    
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, y_train)
    pred_i = knn.predict(x_test)
    err.append(np.mean(pred_i != y_test))

# %%
plt.figure(figsize=(14, 8))
plt.plot(range(1, 30), err, color='green', linestyle='dotted', marker='o',
         markerfacecolor='red', markersize=12)
plt.xlabel('Numero di k')
plt.ylabel('Tasso di errore')
# Out:
# Text(0, 0.5, 'Tasso di errore')

# %%
knn = KNeighborsClassifier(n_neighbors=11)
knn.fit(x_train, y_train)
knn_pred = knn.predict(x_test)
print(confusion_matrix(y_test, knn_pred))
print(classification_report(y_test, knn_pred))
# Out:
# [[1626    4]
#  [  10 1858]]
#               precision    recall  f1-score   support
#
#        False       0.99      1.00      1.00      1630
#         True       1.00      0.99      1.00      1868
#
#     accuracy                           1.00      3498
#    macro avg       1.00      1.00      1.00      3498
# weighted avg       1.00      1.00      1.00      3498
